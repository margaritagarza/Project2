# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
from sqlalchemy import create_engine
import numpy as np

# %% [markdown]
# ## Extract the greatest books ever written using BeautifulSoup from:
# https://www.britannica.com/list/12-novels-considered-the-greatest-book-ever-written

# %%
# URL of page to be scraped
url = "https://www.britannica.com/list/12-novels-considered-the-greatest-book-ever-written"

# Retrieve page with the requests module
response = requests.get(url)

# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Explore the BeautifulSoup object and retrive the book titles into a DataFrame. 
titles = soup.find_all('h2')
greatest_ever_written = []

for title in titles:
    greatest_ever_written.append(title.text)

greatest_ever_written_df = pd.DataFrame(greatest_ever_written,columns=['title'])

#Add a column to identify those books that are best ever written according to Britannic Encyclopedia.
greatest_ever_written_df['best_ever_written']= True
greatest_ever_written_df
# Out:
#                             title  best_ever_written
# 0                   Anna Karenina               True
# 1           To Kill a Mockingbird               True
# 2                The Great Gatsby               True
# 3   One Hundred Years of Solitude               True
# 4              A Passage to India               True
# 5                   Invisible Man               True
# 6                     Don Quixote               True
# 7                         Beloved               True
# 8                   Mrs. Dalloway               True
# 9               Things Fall Apart               True
# 10                      Jane Eyre               True
# 11               The Color Purple               True

# %% [markdown]
# ## Extract books rating information from CSV file found in:
# https://www.kaggle.com/jealousleopard/goodreadsbooks

# %%
# Open CSV file and convert it to pandas DataFrame
csv_file = "books.csv"
books_csv_df = pd.read_csv(csv_file,error_bad_lines=False)
books_csv_df.count()
# Out:
# b'Skipping line 3350: expected 12 fields, saw 13\nSkipping line 4704: expected 12 fields, saw 13\nSkipping line 5879: expected 12 fields, saw 13\nSkipping line 8981: expected 12 fields, saw 13\n'
# bookID                11123
# title                 11123
# authors               11123
# average_rating        11123
# isbn                  11123
# isbn13                11123
# language_code         11123
#   num_pages           11123
# ratings_count         11123
# text_reviews_count    11123
# publication_date      11123
# publisher             11123
# dtype: int64

# %% [markdown]
# ### Transform: Cleaning Rating Data frame

# %%
# new data frame with split value columns 
new = books_csv_df["title"].str.split('[-(]', n = 1, expand = True) 
author_new = books_csv_df["authors"].str.split('/', n = 1, expand = True) 
  
# making separate first name column from new data frame 
books_csv_df["title"]= new[0] 
books_csv_df["authors"]= author_new[0] 

# df display 
books_csv_df.to_csv('books_df.csv')
books_csv_df
# Out:
#        bookID                                             title  \
# 0           1                         Harry Potter and the Half
# 1           2        Harry Potter and the Order of the Phoenix
# 2           4          Harry Potter and the Chamber of Secrets
# 3           5         Harry Potter and the Prisoner of Azkaban
# 4           8                   Harry Potter Boxed Set  Books 1
# ...       ...                                               ...
# 11118   45631  Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                       You Bright and Risen Angels
# 11120   45634                                           The Ice
# 11121   45639                                       Poor People
# 11122   45641                       Las aventuras de Tom Sawyer
#
#                    authors  average_rating        isbn         isbn13  \
# 0             J.K. Rowling            4.57  0439785960  9780439785969
# 1             J.K. Rowling            4.49  0439358078  9780439358071
# 2             J.K. Rowling            4.42  0439554896  9780439554893
# 3             J.K. Rowling            4.56  043965548X  9780439655484
# 4             J.K. Rowling            4.78  0439682584  9780439682589
# ...                    ...             ...         ...            ...
# 11118  William T. Vollmann            4.06  1560254416  9781560254416
# 11119  William T. Vollmann            4.08  0140110879  9780140110876
# 11120  William T. Vollmann            3.96  0140131965  9780140131963
# 11121  William T. Vollmann            3.72  0060878827  9780060878825
# 11122           Mark Twain            3.91  8497646983  9788497646987
#
#       language_code    num_pages  ratings_count  text_reviews_count  \
# 0               eng          652        2095690               27591
# 1               eng          870        2153167               29221
# 2               eng          352           6333                 244
# 3               eng          435        2339585               36325
# 4               eng         2690          41428                 164
# ...             ...          ...            ...                 ...
# 11118           eng          512            156                  20
# 11119           eng          635            783                  56
# 11120           eng          415            820                  95
# 11121           eng          434            769                 139
# 11122           spa          272            113                  12
#
#       publication_date        publisher
# 0            9/16/2006  Scholastic Inc.
# 1             9/1/2004  Scholastic Inc.
# 2            11/1/2003       Scholastic
# 3             5/1/2004  Scholastic Inc.
# 4            9/13/2004       Scholastic
# ...                ...              ...
# 11118       12/21/2004    Da Capo Press
# 11119        12/1/1988    Penguin Books
# 11120         8/1/1993    Penguin Books
# 11121        2/27/2007             Ecco
# 11122        5/28/2006    Edimat Libros
#
# [11123 rows x 12 columns]

# %%
# Select only the information needed from the csv_df
books_review_df = books_csv_df[['title', 'authors','average_rating', 'ratings_count', 'text_reviews_count']].copy()
books_review_df = books_review_df.rename(columns={'  num_pages': 'num_pages', 'Author(s)':'authors'})
books_review_df
# Out:
#                                                   title              authors  \
# 0                             Harry Potter and the Half         J.K. Rowling
# 1            Harry Potter and the Order of the Phoenix          J.K. Rowling
# 2              Harry Potter and the Chamber of Secrets          J.K. Rowling
# 3             Harry Potter and the Prisoner of Azkaban          J.K. Rowling
# 4                       Harry Potter Boxed Set  Books 1         J.K. Rowling
# ...                                                 ...                  ...
# 11118  Expelled from Eden: A William T. Vollmann Reader  William T. Vollmann
# 11119                       You Bright and Risen Angels  William T. Vollmann
# 11120                                           The Ice  William T. Vollmann
# 11121                                       Poor People  William T. Vollmann
# 11122                       Las aventuras de Tom Sawyer           Mark Twain
#
#        average_rating  ratings_count  text_reviews_count
# 0                4.57        2095690               27591
# 1                4.49        2153167               29221
# 2                4.42           6333                 244
# 3                4.56        2339585               36325
# 4                4.78          41428                 164
# ...               ...            ...                 ...
# 11118            4.06            156                  20
# 11119            4.08            783                  56
# 11120            3.96            820                  95
# 11121            3.72            769                 139
# 11122            3.91            113                  12
#
# [11123 rows x 5 columns]

# %%
# Select the publisher with more ratings_count per book
ratigns_df = books_review_df.sort_values(['title', 'ratings_count'], ascending=[True, False])
ratigns_df_clean = ratigns_df.drop_duplicates(subset='title', keep="first")
ratigns_df_clean.to_csv('ever_written.csv')
ratigns_df_clean
# Out:
#                                                   title           authors  \
# 1847                      said the shotgun to the head.     Saul Williams
# 4072  $30 Film School: How to Write  Direct  Produce...   Michael W. Dean
# 1572                                       'Salem's Lot      Stephen King
# 3137                 1 000 Places to See Before You Die  Patricia Schultz
# 2343                                      10 lb Penalty      Dick Francis
# ...                                                 ...               ...
# 8316                                           鋼之鍊金術師 6    Hiromu Arakawa
# 8322                                           鋼之鍊金術師 7    Hiromu Arakawa
# 8319                                           鋼之鍊金術師 9    Hiromu Arakawa
# 4268                                         魔戒二部曲：雙城奇謀    J.R.R. Tolkien
# 4261                                         魔戒首部曲：魔戒現身    J.R.R. Tolkien
#
#       average_rating  ratings_count  text_reviews_count
# 1847            4.22           2762                 214
# 4072            3.49             30                   4
# 1572            4.25          84123                 571
# 3137            3.85          36303                 439
# 2343            3.90           3490                 177
# ...              ...            ...                 ...
# 8316            4.58              5                   0
# 8322            4.57              5                   0
# 8319            4.57              4                   0
# 4268            4.44             24                   0
# 4261            4.36             26                   0
#
# [10275 rows x 5 columns]

# %% [markdown]
# ## Extract Best Seller Books from a website using pandas.
# https://en.wikipedia.org/wiki/List_of_best-selling_books

# %%
#Extract HTML tables into DataFrames
html_link = "https://en.wikipedia.org/wiki/List_of_best-selling_books"
best_selling=pd.read_html(html_link)

total_tables_found=len(best_selling)
print(f"There's a Total of {total_tables_found} tables found on the Wikipedia HTML")

print("The useful set of tables range from 1-5")
# Out:
# There's a Total of 17 tables found on the Wikipedia HTML
# The useful set of tables range from 1-5

# %%
#Loop to retrieve and merge each Table(df)
best_selling_df=best_selling[1]

for i in range(2,6):
    best_selling_df=best_selling_df.append(best_selling[i],ignore_index=True)
    
best_selling_df
# Out:
#                                                   Book  \
# 0                                 A Tale of Two Cities
# 1                  The Little Prince (Le Petit Prince)
# 2             Harry Potter and the Philosopher's Stone
# 3                                           The Hobbit
# 4                             And Then There Were None
# ..                                                 ...
# 160                                   The Front Runner
# 161                                           The Goal
# 162                                     Fahrenheit 451
# 163                                     Angela's Ashes
# 164  The Story of My Experiments with Truth (સત્યના...
#
#                       Author(s) Original language First published  \
# 0               Charles Dickens           English            1859
# 1      Antoine de Saint-Exupéry            French            1943
# 2                 J. K. Rowling           English            1997
# 3              J. R. R. Tolkien           English            1937
# 4               Agatha Christie           English            1939
# ..                          ...               ...             ...
# 160        Patricia Nell Warren           English            1974
# 161         Eliyahu M. Goldratt           English            1984
# 162                Ray Bradbury           English            1953
# 163               Frank McCourt           English            1996
# 164  Mohandas Karamchand Gandhi          Gujarati       1925-1929
#
#                        Approximate sales                   Genre
# 0                        200 million[15]      Historical fiction
# 1    150 million[16][17][18][19][20][21]  fantasy (picture book)
# 2                     120 million[9][22]        fantasy, mystery
# 3                      100+ million [15]                 fantasy
# 4                        100 million[15]                 mystery
# ..                                   ...                     ...
# 160                      10 million[169]                     NaN
# 161                      10 million[170]                     NaN
# 162                      10 million[171]                     NaN
# 163                      10 million[172]                     NaN
# 164                      10 million[173]                     NaN
#
# [165 rows x 6 columns]

# %% [markdown]
# ### Transform: Cleaning Best Selling Books Data Frame

# %%
#Clean Approximate sales
best_selling_df['Approximate sales']= best_selling_df['Approximate sales'].str.split(' million').str[0]
best_selling_df['Approximate sales']= best_selling_df['Approximate sales'].str.split('–').str[0]
best_selling_df['Approximate sales']= best_selling_df['Approximate sales'].str.split('+').str[0]

best_selling_df.at[best_selling_df.index[best_selling_df['Approximate sales']=='>80'],['Approximate sales']]= 80

best_selling_df
# Out:
#                                                   Book  \
# 0                                 A Tale of Two Cities
# 1                  The Little Prince (Le Petit Prince)
# 2             Harry Potter and the Philosopher's Stone
# 3                                           The Hobbit
# 4                             And Then There Were None
# ..                                                 ...
# 160                                   The Front Runner
# 161                                           The Goal
# 162                                     Fahrenheit 451
# 163                                     Angela's Ashes
# 164  The Story of My Experiments with Truth (સત્યના...
#
#                       Author(s) Original language First published  \
# 0               Charles Dickens           English            1859
# 1      Antoine de Saint-Exupéry            French            1943
# 2                 J. K. Rowling           English            1997
# 3              J. R. R. Tolkien           English            1937
# 4               Agatha Christie           English            1939
# ..                          ...               ...             ...
# 160        Patricia Nell Warren           English            1974
# 161         Eliyahu M. Goldratt           English            1984
# 162                Ray Bradbury           English            1953
# 163               Frank McCourt           English            1996
# 164  Mohandas Karamchand Gandhi          Gujarati       1925-1929
#
#     Approximate sales                   Genre
# 0                 200      Historical fiction
# 1                 150  fantasy (picture book)
# 2                 120        fantasy, mystery
# 3                 100                 fantasy
# 4                 100                 mystery
# ..                ...                     ...
# 160                10                     NaN
# 161                10                     NaN
# 162                10                     NaN
# 163                10                     NaN
# 164                10                     NaN
#
# [165 rows x 6 columns]

# %%
# Cleaning First published
best_selling_df['First published']=best_selling_df['First published'].astype('str')
best_selling_df.at[best_selling_df.index[best_selling_df['First published'] =='1925-1929'],['First published']]= '1925'


best_selling_df['First published'].unique()
# Out:
# array(['1859', '1943', '1997', '1937', '1939', '1791', '1950', '1887',
#        '1881', '2003', '1998', '1999', '2000', '2005', '2007', '1988',
#        '1951', '1992', '1880', '1984', '1967', '1955', '1946', '1908',
#        '1877', '1980', '1975', '1972', '1976', '1952', '1902', '1970',
#        '1969', '1899', '1960', '1979', '1991', '1932', '1869', '1947',
#        '1977', '2002', '1966', '1925', '1936', '1938', '1949', '2009',
#        '2008', '1945', '1788', '1934', '1989', '1935', '1993', '2012',
#        '2010', '1957', '2015', '1929', '1974', '1958', '2004', '1971',
#        '1986', '1885', '1982', '1813', '1923', '1963', '2006', '1973',
#        '1965', '1964', '1968', '1981', '1995', '2011', '1994', '1942',
#        '1985', '2001', '1933', '1962', '1987', '1956', '1948', '1304',
#        '2018', '1961', '1978', '1953', '1996'], dtype=object)

# %%
#Fix Book names where there are two titles(English and Original language)
best_selling_df['Book']= best_selling_df['Book'].str.split('(').str[0]
best_selling_df.tail()
# Out:
#                                         Book                   Author(s)  \
# 160                         The Front Runner        Patricia Nell Warren
# 161                                 The Goal         Eliyahu M. Goldratt
# 162                           Fahrenheit 451                Ray Bradbury
# 163                           Angela's Ashes               Frank McCourt
# 164  The Story of My Experiments with Truth   Mohandas Karamchand Gandhi
#
#     Original language First published Approximate sales Genre
# 160           English            1974                10   NaN
# 161           English            1984                10   NaN
# 162           English            1953                10   NaN
# 163           English            1996                10   NaN
# 164          Gujarati            1925                10   NaN

# %%
#Fix Author "E.B. White; illustrated by Garth Williams"
best_selling_df.at[best_selling_df.index[best_selling_df['Author(s)'] =='E.B. White; illustrated by Garth Williams'],['Author(s)']]= 'E.B. White'

# %%
# Check for repeatedness on Languages
print (best_selling_df['Original language'].unique())
# Out:
# ['English' 'French' 'Chinese' 'Italian' 'Portuguese' 'Spanish'
#  'Swiss German' 'Norwegian' 'Russian' 'Dutch' 'Swedish' 'Japanese' 'Hindi'
#  'German' 'Czech' 'Yiddish' 'Gujarati']

# %%
#Change Swiss German language to German
best_selling_df.at[best_selling_df.index[best_selling_df['Original language'] =='Swiss German'],['Original language']]= 'German'
best_selling_df['Original language'].unique()
# Out:
# array(['English', 'French', 'Chinese', 'Italian', 'Portuguese', 'Spanish',
#        'German', 'Norwegian', 'Russian', 'Dutch', 'Swedish', 'Japanese',
#        'Hindi', 'Czech', 'Yiddish', 'Gujarati'], dtype=object)

# %%
best_selling_df['Genre'].unique()
# Out:
# array(['Historical fiction', 'fantasy (picture book)', 'fantasy, mystery',
#        'fantasy', 'mystery', 'family saga', 'adventure',
#        'mystery thriller', 'coming-of-age', 'romance', 'historical',
#        'self-improvement', 'magic realism', 'general',
#        "children's fiction", 'manual', "children's literature",
#        'historical novel, mystery', 'war, thriller', nan], dtype=object)

# %%
best_selling_df = best_selling_df.replace({'Genre': {"Historical fiction": "fiction", "fantasy (picture book)": "fantasy", 
                                                     "fantasy, mystery":"fantasy", "mystery thriller":"mystery", 
                                                     "children's fiction":"children's literature",
                                                     "historical novel, mystery":"mystery","war, thriller":"thriller" }})
best_selling_df
# Out:
#                                          Book                   Author(s)  \
# 0                        A Tale of Two Cities             Charles Dickens
# 1                          The Little Prince     Antoine de Saint-Exupéry
# 2    Harry Potter and the Philosopher's Stone               J. K. Rowling
# 3                                  The Hobbit            J. R. R. Tolkien
# 4                    And Then There Were None             Agatha Christie
# ..                                        ...                         ...
# 160                          The Front Runner        Patricia Nell Warren
# 161                                  The Goal         Eliyahu M. Goldratt
# 162                            Fahrenheit 451                Ray Bradbury
# 163                            Angela's Ashes               Frank McCourt
# 164   The Story of My Experiments with Truth   Mohandas Karamchand Gandhi
#
#     Original language First published Approximate sales    Genre
# 0             English            1859               200  fiction
# 1              French            1943               150  fantasy
# 2             English            1997               120  fantasy
# 3             English            1937               100  fantasy
# 4             English            1939               100  mystery
# ..                ...             ...               ...      ...
# 160           English            1974                10      NaN
# 161           English            1984                10      NaN
# 162           English            1953                10      NaN
# 163           English            1996                10      NaN
# 164          Gujarati            1925                10      NaN
#
# [165 rows x 6 columns]

# %%
# Change column names to match SQL column titles
best_selling_df=best_selling_df.rename(columns={'Book':'title',
                               'Author(s)':'authors',
                               'Original language':'original_language',
                               'First published':'first_published',
                               'Approximate sales':'approximate_sales',
                               'Genre':'genre'})
best_selling_df
# Out:
#                                         title                     authors  \
# 0                        A Tale of Two Cities             Charles Dickens
# 1                          The Little Prince     Antoine de Saint-Exupéry
# 2    Harry Potter and the Philosopher's Stone               J. K. Rowling
# 3                                  The Hobbit            J. R. R. Tolkien
# 4                    And Then There Were None             Agatha Christie
# ..                                        ...                         ...
# 160                          The Front Runner        Patricia Nell Warren
# 161                                  The Goal         Eliyahu M. Goldratt
# 162                            Fahrenheit 451                Ray Bradbury
# 163                            Angela's Ashes               Frank McCourt
# 164   The Story of My Experiments with Truth   Mohandas Karamchand Gandhi
#
#     original_language first_published approximate_sales    genre
# 0             English            1859               200  fiction
# 1              French            1943               150  fantasy
# 2             English            1997               120  fantasy
# 3             English            1937               100  fantasy
# 4             English            1939               100  mystery
# ..                ...             ...               ...      ...
# 160           English            1974                10      NaN
# 161           English            1984                10      NaN
# 162           English            1953                10      NaN
# 163           English            1996                10      NaN
# 164          Gujarati            1925                10      NaN
#
# [165 rows x 6 columns]

# %%
#Add a column to identify those books that are best ever written according to Britannic Encyclopedia.
best_selling_df['best_seller']= True
best_selling_df
# Out:
#                                         title                     authors  \
# 0                        A Tale of Two Cities             Charles Dickens
# 1                          The Little Prince     Antoine de Saint-Exupéry
# 2    Harry Potter and the Philosopher's Stone               J. K. Rowling
# 3                                  The Hobbit            J. R. R. Tolkien
# 4                    And Then There Were None             Agatha Christie
# ..                                        ...                         ...
# 160                          The Front Runner        Patricia Nell Warren
# 161                                  The Goal         Eliyahu M. Goldratt
# 162                            Fahrenheit 451                Ray Bradbury
# 163                            Angela's Ashes               Frank McCourt
# 164   The Story of My Experiments with Truth   Mohandas Karamchand Gandhi
#
#     original_language first_published approximate_sales    genre  best_seller
# 0             English            1859               200  fiction         True
# 1              French            1943               150  fantasy         True
# 2             English            1997               120  fantasy         True
# 3             English            1937               100  fantasy         True
# 4             English            1939               100  mystery         True
# ..                ...             ...               ...      ...          ...
# 160           English            1974                10      NaN         True
# 161           English            1984                10      NaN         True
# 162           English            1953                10      NaN         True
# 163           English            1996                10      NaN         True
# 164          Gujarati            1925                10      NaN         True
#
# [165 rows x 7 columns]

# %% [markdown]
# ### Transform: Prepare dataframes to load into the Database

# %%
# Join best ever written and best seller data frames 

best_books = best_selling_df.merge(greatest_ever_written_df, on='title', how='outer')

# Eliminate NULLs from best_seller and best_ever_written columns (they should be boolean)
best_books_df = best_books.fillna({'best_seller': False,'best_ever_written': False,'authors': "",
                                  'original_language': 'Undefined','first_published': 9999, 'genre': 'Undefined'})
best_books_df
# Out:
#                                         title                   authors  \
# 0                        A Tale of Two Cities           Charles Dickens
# 1                          The Little Prince   Antoine de Saint-Exupéry
# 2    Harry Potter and the Philosopher's Stone             J. K. Rowling
# 3                                  The Hobbit          J. R. R. Tolkien
# 4                    And Then There Were None           Agatha Christie
# ..                                        ...                       ...
# 169                               Don Quixote
# 170                                   Beloved
# 171                             Mrs. Dalloway
# 172                                 Jane Eyre
# 173                          The Color Purple
#
#     original_language first_published approximate_sales      genre  \
# 0             English            1859               200    fiction
# 1              French            1943               150    fantasy
# 2             English            1997               120    fantasy
# 3             English            1937               100    fantasy
# 4             English            1939               100    mystery
# ..                ...             ...               ...        ...
# 169         Undefined            9999               NaN  Undefined
# 170         Undefined            9999               NaN  Undefined
# 171         Undefined            9999               NaN  Undefined
# 172         Undefined            9999               NaN  Undefined
# 173         Undefined            9999               NaN  Undefined
#
#      best_seller  best_ever_written
# 0           True              False
# 1           True              False
# 2           True              False
# 3           True              False
# 4           True              False
# ..           ...                ...
# 169        False               True
# 170        False               True
# 171        False               True
# 172        False               True
# 173        False               True
#
# [174 rows x 8 columns]

# %%
#Join with ratings Data Frame to fill the missing authors 
best_ratings = best_books_df.merge(ratigns_df_clean, on='title', how='left')

for x in range(len(best_ratings)):
    if best_ratings.iloc[x,1] == "":
        best_ratings.iloc[x,1] = best_ratings.iloc[x,8]

best_books_final = best_ratings[['title','authors_x', 'original_language','first_published','approximate_sales','genre','best_ever_written','best_seller']].copy()
best_books_final.columns=['title','author', 'original_language','first_published','approximate_sales','genre','best_ever_written','best_seller']


best_books_final
# Out:
#                                         title                        author  \
# 0                        A Tale of Two Cities               Charles Dickens
# 1                          The Little Prince       Antoine de Saint-Exupéry
# 2    Harry Potter and the Philosopher's Stone                 J. K. Rowling
# 3                                  The Hobbit              J. R. R. Tolkien
# 4                    And Then There Were None               Agatha Christie
# ..                                        ...                           ...
# 169                               Don Quixote  Miguel de Cervantes Saavedra
# 170                                   Beloved                 Toni Morrison
# 171                             Mrs. Dalloway                Virginia Woolf
# 172                                 Jane Eyre              Charlotte Brontë
# 173                          The Color Purple                  Alice Walker
#
#     original_language first_published approximate_sales      genre  \
# 0             English            1859               200    fiction
# 1              French            1943               150    fantasy
# 2             English            1997               120    fantasy
# 3             English            1937               100    fantasy
# 4             English            1939               100    mystery
# ..                ...             ...               ...        ...
# 169         Undefined            9999               NaN  Undefined
# 170         Undefined            9999               NaN  Undefined
# 171         Undefined            9999               NaN  Undefined
# 172         Undefined            9999               NaN  Undefined
# 173         Undefined            9999               NaN  Undefined
#
#      best_ever_written  best_seller
# 0                False         True
# 1                False         True
# 2                False         True
# 3                False         True
# 4                False         True
# ..                 ...          ...
# 169               True        False
# 170               True        False
# 171               True        False
# 172               True        False
# 173               True        False
#
# [174 rows x 8 columns]

# %%
# Original Language data frame 
language_list = best_books_final['original_language'].unique()
language_df = pd.DataFrame(language_list,columns=['original_language'])
language_df['id_language']=""

counter = 1000
for x in range(len(language_df)):
    counter += 1
    language_df.iloc[x,1]= f'l-{counter}'

language_df
# Out:
#    original_language id_language
# 0            English      l-1001
# 1             French      l-1002
# 2            Chinese      l-1003
# 3            Italian      l-1004
# 4         Portuguese      l-1005
# 5            Spanish      l-1006
# 6             German      l-1007
# 7          Norwegian      l-1008
# 8            Russian      l-1009
# 9              Dutch      l-1010
# 10           Swedish      l-1011
# 11          Japanese      l-1012
# 12             Hindi      l-1013
# 13             Czech      l-1014
# 14           Yiddish      l-1015
# 15          Gujarati      l-1016
# 16         Undefined      l-1017

# %%
# Authors data frame 
authors_list = best_books_final['author'].unique()
authors_df = pd.DataFrame(authors_list,columns=['author'])
authors_df['id_author']=""

counter = 1000
for x in range(len(authors_df)):
    counter += 1
    authors_df.iloc[x,1]= f'a-{counter}'

    
authors_df
# Out:
#                            author id_author
# 0                 Charles Dickens    a-1001
# 1        Antoine de Saint-Exupéry    a-1002
# 2                   J. K. Rowling    a-1003
# 3                J. R. R. Tolkien    a-1004
# 4                 Agatha Christie    a-1005
# ..                            ...       ...
# 152  Miguel de Cervantes Saavedra    a-1153
# 153                 Toni Morrison    a-1154
# 154                Virginia Woolf    a-1155
# 155              Charlotte Brontë    a-1156
# 156                  Alice Walker    a-1157
#
# [157 rows x 2 columns]

# %%
# Eliminate blank spaces 
authors_df['author']=authors_df['author'].str.strip()
authors_df['author'].str.len().max()
# Out:
# 39

# %%
# Genre data frame 
genre_list = best_books_final['genre'].unique()
genre_df = pd.DataFrame(genre_list,columns=['genre'])
genre_df['id_genre']=""

counter = 1000
for x in range(len(genre_df)):
    counter += 1
    genre_df.iloc[x,1]= f'a-{counter}'

genre_df
# Out:
#                     genre id_genre
# 0                 fiction   a-1001
# 1                 fantasy   a-1002
# 2                 mystery   a-1003
# 3             family saga   a-1004
# 4               adventure   a-1005
# 5           coming-of-age   a-1006
# 6                 romance   a-1007
# 7              historical   a-1008
# 8        self-improvement   a-1009
# 9           magic realism   a-1010
# 10                general   a-1011
# 11  children's literature   a-1012
# 12                 manual   a-1013
# 13               thriller   a-1014
# 14              Undefined   a-1015

# %%
# Eliminate blank spaces 
genre_df['genre']=genre_df['genre'].str.strip()
genre_df['genre'].str.len().max()
# Out:
# 21

# %%
# Best Books Data Frame

best_books_final['id_title']=""

counter = 1000
for x in range(len(best_books_final)):
    counter += 1
    best_books_final.iloc[x,8]= f't-{counter}'
        
    for y in range(len(authors_df)):
        if authors_df.iloc[y,0] == best_books_final.iloc[x,1]:
            best_books_final.iloc[x,1] = authors_df.iloc[y,1]
            break
    
    for z in range(len(genre_df)):
        if genre_df.iloc[z,0] == best_books_final.iloc[x,5]:
            best_books_final.iloc[x,5] = genre_df.iloc[z,1]
            break
    
    for w in range(len(language_df)):
        if language_df.iloc[w,0] == best_books_final.iloc[x,2]:
            best_books_final.iloc[x,2] = language_df.iloc[w,1]
            break
    
best_books=best_books_final.rename(columns={'author':'id_author','original_language':'id_language','genre':'id_genre'})
best_books
# Out:
#                                         title id_author id_language  \
# 0                        A Tale of Two Cities    a-1001      l-1001
# 1                          The Little Prince     a-1002      l-1002
# 2    Harry Potter and the Philosopher's Stone    a-1003      l-1001
# 3                                  The Hobbit    a-1004      l-1001
# 4                    And Then There Were None    a-1005      l-1001
# ..                                        ...       ...         ...
# 169                               Don Quixote    a-1153      l-1017
# 170                                   Beloved    a-1154      l-1017
# 171                             Mrs. Dalloway    a-1155      l-1017
# 172                                 Jane Eyre    a-1156      l-1017
# 173                          The Color Purple    a-1157      l-1017
#
#     first_published approximate_sales id_genre  best_ever_written  \
# 0              1859               200   a-1001              False
# 1              1943               150   a-1002              False
# 2              1997               120   a-1002              False
# 3              1937               100   a-1002              False
# 4              1939               100   a-1003              False
# ..              ...               ...      ...                ...
# 169            9999               NaN   a-1015               True
# 170            9999               NaN   a-1015               True
# 171            9999               NaN   a-1015               True
# 172            9999               NaN   a-1015               True
# 173            9999               NaN   a-1015               True
#
#      best_seller id_title
# 0           True   t-1001
# 1           True   t-1002
# 2           True   t-1003
# 3           True   t-1004
# 4           True   t-1005
# ..           ...      ...
# 169        False   t-1170
# 170        False   t-1171
# 171        False   t-1172
# 172        False   t-1173
# 173        False   t-1174
#
# [174 rows x 9 columns]

# %%
# Eliminate blank spaces 
best_books['title']=best_books['title'].str.strip()
best_books['title'].str.len().max()
# Out:
# 44

# %%
# Ratings Data Frame 
ratings_data = best_books.merge(ratigns_df_clean, on='title', how='inner')
ratings_data_final = ratings_data[['title','average_rating','ratings_count', 'text_reviews_count']].copy()
ratings_data_final.columns=['title','average_rating','ratings_count', 'text_reviews_count']

counter = 1000
ratings_data_final['id_rating']=""
for x in range(len(ratings_data_final)):
    counter += 1
    ratings_data_final.iloc[x,4]= f'r-{counter}'
    
    for y in range(len(best_books)):
        if best_books.iloc[y,0] == ratings_data_final.iloc[x,0]:
            ratings_data_final.iloc[x,0] = best_books.iloc[y,8]
            break

ratings_data_final=ratings_data_final.rename(columns={'title':'id_title'})
len(ratings_data_final)
# Out:
# 65

# %%
ratings_data_final
# Out:
#    id_title  average_rating  ratings_count  text_reviews_count id_rating
# 0    t-1001            3.84           1343                 183    r-1001
# 1    t-1004            4.27           3213                 329    r-1002
# 2    t-1005            4.26         625767               18785    r-1003
# 3    t-1010            3.84          13934                1459    r-1004
# 4    t-1017            3.86        1631221               55843    r-1005
# ..      ...             ...            ...                 ...       ...
# 60   t-1170            3.87         160911                4087    r-1061
# 61   t-1171            3.83         282045                9004    r-1062
# 62   t-1172            3.79         176190                5595    r-1063
# 63   t-1173            4.12        1409369               27884    r-1064
# 64   t-1174            4.20         445206                9643    r-1065
#
# [65 rows x 5 columns]

# %%
# Eliminate blank spaces 
ratings_data_final['id_title']=ratings_data_final['id_title'].str.strip()
ratings_data_final['id_title'].str.len().max()
# Out:
# 6

# %% [markdown]
# ## Create database connection

# %%
rds_connection_string = "postgres:Accm84$1@localhost:5432/best_books_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2344         try:
# -> 2345             return fn()
#    2346         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     489         # inherits the docstring from interfaces.Dialect.connect
# --> 490         return self.dbapi.connect(*cargs, **cparams)
#     491
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-35-d72bc75a6b62> in <module>
# ----> 1 engine.table_names()
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2323         """
#    2324
# -> 2325         with self._optional_conn_ctx_manager(connection) as conn:
#    2326             return self.dialect.get_table_names(conn, schema)
#    2327
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2093     def _optional_conn_ctx_manager(self, connection=None):
#    2094         if connection is None:
# -> 2095             with self._contextual_connect() as conn:
#    2096                 yield conn
#    2097         else:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2309         return self._connection_cls(
#    2310             self,
# -> 2311             self._wrap_pool_connect(self.pool.connect, None),
#    2312             close_with_result=close_with_result,
#    2313             **kwargs
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2346         except dialect.dbapi.Error as e:
#    2347             if connection is None:
# -> 2348                 Connection._handle_dbapi_exception_noconnection(
#    2349                     e, dialect, self
#    2350                 )
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1588             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1589         elif should_wrap:
# -> 1590             util.raise_(
#    1591                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1592             )
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2343         dialect = self.dialect
#    2344         try:
# -> 2345             return fn()
#    2346         except dialect.dbapi.Error as e:
#    2347             if connection is None:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     488     def connect(self, *cargs, **cparams):
#     489         # inherits the docstring from interfaces.Dialect.connect
# --> 490         return self.dbapi.connect(*cargs, **cparams)
#     491
#     492     def create_connect_args(self, url):
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
#
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# ## Load Final Data Frames to Database

# %%
language_df.to_sql(name='original_languages', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2344         try:
# -> 2345             return fn()
#    2346         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     177         try:
# --> 178             raise exception
#     179         finally:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     489         # inherits the docstring from interfaces.Dialect.connect
# --> 490         return self.dbapi.connect(*cargs, **cparams)
#     491
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-36-5a67641d8024> in <module>
# ----> 1 language_df.to_sql(name='original_languages', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2651         from pandas.io import sql
#    2652
# -> 2653         sql.to_sql(
#    2654             self,
#    2655             name,
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     510         )
#     511
# --> 512     pandas_sql.to_sql(
#     513         frame,
#     514         name,
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1314             dtype=dtype,
#    1315         )
# -> 1316         table.create()
#    1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\pandas\io\sql.py in create(self)
#     642
#     643     def create(self):
# --> 644         if self.exists():
#     645             if self.if_exists == "fail":
#     646                 raise ValueError(f"Table '{self.name}' already exists.")
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\pandas\io\sql.py in exists(self)
#     629
#     630     def exists(self):
# --> 631         return self.pd_sql.has_table(self.name, self.schema)
#     632
#     633     def sql_schema(self):
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1338
#    1339     def has_table(self, name, schema=None):
# -> 1340         return self.connectable.run_callable(
#    1341             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1342         )
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2218
#    2219         """
# -> 2220         with self._contextual_connect() as conn:
#    2221             return conn.run_callable(callable_, *args, **kwargs)
#    2222
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2309         return self._connection_cls(
#    2310             self,
# -> 2311             self._wrap_pool_connect(self.pool.connect, None),
#    2312             close_with_result=close_with_result,
#    2313             **kwargs
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2346         except dialect.dbapi.Error as e:
#    2347             if connection is None:
# -> 2348                 Connection._handle_dbapi_exception_noconnection(
#    2349                     e, dialect, self
#    2350                 )
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1588             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1589         elif should_wrap:
# -> 1590             util.raise_(
#    1591                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1592             )
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2343         dialect = self.dialect
#    2344         try:
# -> 2345             return fn()
#    2346         except dialect.dbapi.Error as e:
#    2347             if connection is None:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value, with_traceback=exc_tb,
#      70                 )
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     488     def connect(self, *cargs, **cparams):
#     489         # inherits the docstring from interfaces.Dialect.connect
# --> 490         return self.dbapi.connect(*cargs, **cparams)
#     491
#     492     def create_connect_args(self, url):
#
# ~\Anaconda3\New folder\envs\DataVirtual\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (127.0.0.1) and accepting
# 	TCP/IP connections on port 5432?
# could not connect to server: Connection refused (0x0000274D/10061)
# 	Is the server running on host "localhost" (::1) and accepting
# 	TCP/IP connections on port 5432?
#
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
authors_df.to_sql(name='authors', con=engine, if_exists='append', index=False)

# %%
genre_df.to_sql(name='genres', con=engine, if_exists='append', index=False)

# %%
best_books.to_sql(name='best_books', con=engine, if_exists='append', index=False)

# %%
ratings_data_final.to_sql(name='ratings_data', con=engine, if_exists='append', index=False)
